# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjay-agalave/google-colab-notebook/blob/main/python_basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Basic Python

# %%
a = 1
b = 1
if a > b:
  print("A is greater then B", a)
elif a == b:
  print("Both are equl")
else:
  print("B is greater then A", b)
# Out:
# Both are equl
