# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjay-agalave/google-colab-notebook/blob/main/Overview_of_Colaboratory_Features.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("This is my first code in google colab")
# Out:
# This is my first code in google colab
